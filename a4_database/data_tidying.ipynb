# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.0     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
# tidying the populations dataset
populations <- read.csv("../data/population_per_province_data.csv")
head(populations)

# turn the columns into rows
pops_pivoted <- populations |> pivot_longer(!Geography, names_to = "period", values_to = "count")
head(pops_pivoted)

# split the 'period' column into quarter and year
pops_split <- pops_pivoted %>% separate_wider_delim(period, ".", names = c("quarter", "year"))
head(pops_split)

# # only keep rows where quarter = Q4, because this is this population at the end of each year
pops_sum <- pops_split |>
            filter(quarter == "Q4")|>
            select(-quarter)
pops_sum
write.csv(pops_sum, "../data/tidied_population_estimates.csv",row.names = FALSE)
# Out:
#   Geography                 Q1.2012  Q2.2012  Q3.2012  Q4.2012  Q1.2013
# 1 Canada                    34516032 34592192 34713395 34834973 34881794
# 2 Newfoundland and Labrador   526115   525550   526235   527065   527129
# 3 Prince Edward Island        144208   144365   144415   144396   144041
# 4 Nova Scotia                 943907   943317   943163   942829   942045
# 5 New Brunswick               757039   757024   758121   758408   758026
# 6 Quebec                     8028516  8038332  8059752  8076838  8081006
#   Q2.2013  Q3.2013  Q4.2013  Q1.2014  ⋯ Q3.2019  Q4.2019  Q1.2020  Q2.2020
# 1 34956567 35080992 35209597 35247023 ⋯ 37618495 37828162 37928208 38006941
# 2   527177   526960   527948   528065 ⋯   527643   528442   528231   527733
# 3   143807   143942   143943   143828 ⋯   155792   157025   157494   158401
# 4   940647   939808   939442   939166 ⋯   975799   982592   984130   986204
# 5   757854   758261   758379   758713 ⋯   777387   780907   781054   782512
# 6  8089004  8108825  8122462  8123138 ⋯  8483186  8521542  8537376  8550900
#   Q3.2020  Q4.2020  Q1.2021  Q2.2021  Q3.2021  Q4.2021
# 1 38028638 38027406 38058291 38140918 38239864 38451454
# 2   526884   526046   525895   526195   527056   528335
# 3   159193   159179   159240   160334   162133   163775
# 4   989168   989154   990025   993946   999908  1006805
# 5   783432   783814   784950   787002   790802   795755
# 6  8551095  8551865  8550561  8556015  8572020  8603553
#   Geography period  count
# 1 Canada    Q1.2012 34516032
# 2 Canada    Q2.2012 34592192
# 3 Canada    Q3.2012 34713395
# 4 Canada    Q4.2012 34834973
# 5 Canada    Q1.2013 34881794
# 6 Canada    Q2.2013 34956567
#   Geography quarter year count
# 1 Canada    Q1      2012 34516032
# 2 Canada    Q2      2012 34592192
# 3 Canada    Q3      2012 34713395
# 4 Canada    Q4      2012 34834973
# 5 Canada    Q1      2013 34881794
# 6 Canada    Q2      2013 34956567
#     Geography                 year count
# 1   Canada                    2012 34834973
# 2   Canada                    2013 35209597
# 3   Canada                    2014 35555305
# 4   Canada                    2015 35823591
# 5   Canada                    2016 36257421
# 6   Canada                    2017 36722075
# 7   Canada                    2018 37259485
# 8   Canada                    2019 37828162
# 9   Canada                    2020 38027406
# 10  Canada                    2021 38451454
# 11  Newfoundland and Labrador 2012   527065
# 12  Newfoundland and Labrador 2013   527948
# 13  Newfoundland and Labrador 2014   528266
# 14  Newfoundland and Labrador 2015   528843
# 15  Newfoundland and Labrador 2016   530368
# 16  Newfoundland and Labrador 2017   530153
# 17  Newfoundland and Labrador 2018   528926
# 18  Newfoundland and Labrador 2019   528442
# 19  Newfoundland and Labrador 2020   526046
# 20  Newfoundland and Labrador 2021   528335
# 21  Prince Edward Island      2012   144396
# 22  Prince Edward Island      2013   143943
# 23  Prince Edward Island      2014   144342
# 24  Prince Edward Island      2015   144949
# 25  Prince Edward Island      2016   147699
# 26  Prince Edward Island      2017   150595
# 27  Prince Edward Island      2018   153906
# 28  Prince Edward Island      2019   157025
# 29  Prince Edward Island      2020   159179
# 30  Prince Edward Island      2021   163775
# ⋮   ⋮                         ⋮    ⋮
# 111 Yukon                     2012 36347
# 112 Yukon                     2013 36384
# 113 Yukon                     2014 37223
# 114 Yukon                     2015 37730
# 115 Yukon                     2016 38724
# 116 Yukon                     2017 39705
# 117 Yukon                     2018 40533
# 118 Yukon                     2019 41460
# 119 Yukon                     2020 42109
# 120 Yukon                     2021 43119
# 121 Northwest Territories 5   2012 43656
# 122 Northwest Territories 5   2013 43727
# 123 Northwest Territories 5   2014 44031
# 124 Northwest Territories 5   2015 44443
# 125 Northwest Territories 5   2016 44471
# 126 Northwest Territories 5   2017 44825
# 127 Northwest Territories 5   2018 44487
# 128 Northwest Territories 5   2019 44512
# 129 Northwest Territories 5   2020 44395
# 130 Northwest Territories 5   2021 44621
# 131 Nunavut 5                 2012 34830
# 132 Nunavut 5                 2013 35536
# 133 Nunavut 5                 2014 36100
# 134 Nunavut 5                 2015 36602
# 135 Nunavut 5                 2016 37084
# 136 Nunavut 5                 2017 37829
# 137 Nunavut 5                 2018 38487
# 138 Nunavut 5                 2019 38893
# 139 Nunavut 5                 2020 39581
# 140 Nunavut 5                 2021 40232

# %%
# tidying the employment dataset
employment <- read.csv("../data/manufacturing_employment_data.csv")
# head(employment)

# # renaming columns 
old_names <- c("naics_industry", "Province", "X2012", "X2013", "X2014", 
               "X2015", "X2016", "X2017", "X2018", "X2019", "X2020", "X2021")
new_names <- c("naics_industry", "province", "2012", "2013", "2014", 
               "2015", "2016", "2017", "2018", "2019", "2020", "2021")
colnames(employment)[colnames(employment) %in% old_names] <- new_names
# head(employment)

emp_pivoted <- employment |> pivot_longer(!naics_industry:province, names_to = "year", values_to = "count")
# head(emp_pivoted)

write.csv(emp_pivoted, "../data/tidied_employment_estimates.csv",row.names = FALSE)
# Out:
#   naics_industry province year count
# 1 Manufacturing  Canada   2012 1776.6
# 2 Manufacturing  Canada   2013 1732.6
# 3 Manufacturing  Canada   2014 1721.7
# 4 Manufacturing  Canada   2015 1734.4
# 5 Manufacturing  Canada   2016 1729.8
# 6 Manufacturing  Canada   2017 1767.5

# %%
# tidying the employment dataset
emissions <- read.csv("../data/emissions_data_per_province.csv")
# head(emissions)

old_names <- c("Geography", "Sector", "X2012", "X2013", "X2014", 
               "X2015", "X2016", "X2017", "X2018", "X2019", "X2020", "X2021")
new_names <- c("province", "ioic_industry", "2012", "2013", "2014", 
               "2015", "2016", "2017", "2018", "2019", "2020", "2021")
colnames(emissions)[colnames(emissions) %in% old_names] <- new_names
# head(emissions)

emissions_pivoted <- emissions |> 
                     pivot_longer(!province:ioic_industry, names_to = "year", values_to = "count")
# head(emissions_pivoted)

write.csv(emissions_pivoted, "../data/tidied_emissions_estimates.csv",row.names = FALSE)
# Out:
#   province
# 1 Canada
# 2 Canada
# 3 Canada
# 4 Canada
# 5 Canada
# 6 Canada
#   ioic_industry
# 1 Total, industries and households
# 2 Total, industries
# 3 Animal food manufacturing  [BS31110]
# 4 Sugar and confectionery product manufacturing  [BS31130]
# 5 Fruit and vegetable preserving and specialty food manufacturing  [BS31140]
# 6 Dairy product manufacturing  [BS31150]
#   2012   2013   2014   2015   2016   2017   2018   2019   2020   2021
# 1 765177 774546 775519 780254 753719 766876 780372 775612 693849 708880
# 2 636925 639396 642314 647912 622641 632545 642939 639121 579689 594661
# 3    254    272    457    321    341    286    384    433    434    421
# 4    352    361    427    466    397    607    370    440    412    484
# 5    805    625    485    526    457    595    484    472    502    493
# 6    451    540    343    385    383    392    434    510    509    524
#   province ioic_industry                    year count
# 1 Canada   Total, industries and households 2012 765177
# 2 Canada   Total, industries and households 2013 774546
# 3 Canada   Total, industries and households 2014 775519
# 4 Canada   Total, industries and households 2015 780254
# 5 Canada   Total, industries and households 2016 753719
# 6 Canada   Total, industries and households 2017 766876

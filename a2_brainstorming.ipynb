# %% [markdown]
# # CPSC 368 Group Project Brainstorming
# <br><br>

# %% [markdown]
# ## Idea #1

# %% [markdown]
# ### 1. Explain the proposed idea.
# Temperature change may have a devastating effect on affected communities by increasing the risk of natural disaster. As such developing a means of predicting sudden temperature changes may be beneficial when allocating humanitarian resources for disaster relief.
#
# This idea explores potential causes of changes in temperature across the Lower Mainland, specifically analyzing precipitation, pressure, air quality, and wind speed.
#
# <br><br>
# ### 2. Identify how the idea relates to the topic chosen by the in-class vote.
# This idea is related to climate and sustainability as we are directly analyzing climate factors and their relationship with each other. In this case, we are investigating the relationship between precipitation, pressure, air quality, wind speed, and temperature.
#
# <br><br>
# ### 3. List three datasets you wish to work with.
# **Dataset #1: Homogenized Surface Air Temperature Data**
# - Link: https://www.canada.ca/en/environment-climate-change/services/climate-change/science-research-data/climate-trends-variability/adjusted-homogenized-canadian-data/surface-air-temperature.html
# <br>
#
# **Dataset #2: Adjusted Precipitation Data**
# - Link: https://www.canada.ca/en/environment-climate-change/services/climate-change/science-research-data/climate-trends-variability/adjusted-homogenized-canadian-data/precipitation.html
# <br>
#
# **Dataset #3: Homogenized Surface Pressure Data**
# - Link: https://www.canada.ca/en/environment-climate-change/services/climate-change/science-research-data/climate-trends-variability/adjusted-homogenized-canadian-data/surface-pressure.html
# <br>
#
# **Dataset #4: Homogenized Surface Wind Speed Data**
# - Link: https://www.canada.ca/en/environment-climate-change/services/climate-change/science-research-data/climate-trends-variability/adjusted-homogenized-canadian-data/surface-wind-speed.html
# <br>
#
# **Dataset #5: Verified Air Quality Readings across BC**
# - Link: https://catalogue.data.gov.bc.ca/dataset/air-quality-and-climate-monitoring-verified-hourly-air-quality-and-meteorological-data
# <br>
#
# **Trustworthiness and reliability:**
# - All five datasets are sourced from the Government of BC’s open source data collection. Although the data collection methods aren’t publicized, we can infer that standards are in place to ensure accuracy and reduce bias.
#
# <br><br>
# ### 4. Describe the data analysis you wish to perform. Specifically, explain:
# **What you are trying to analyze and how will you go about analyzing it?**
# - We are analyzing potential relationships between 4 different components of climate data to see if any affect average temperature. Through this, we can also look at potential causes for changes in the trend of the temperature around BC/the Lower Mainland. This project may require modelling, either linear regression or some other method, to achieve this.
# <br><br>
#
# **Why is this the best method to analyze the data?**
# - This is the best method because we are wanting to make inferences on the data, and use this model to predict future average temperatures given trends of other data. Instead of fitting a model on just temperature data alone, we can use air quality, wind, pressure, and other factors to develop an accurate model.
# <br><br>
#
# **List two other possible ways to approach the problem and explain why you are not using these approaches.**
# - Approach #1: Non-parametric regression (KNN, Decision Trees)
#     - This approach will not be used because assumptions of normality may be reasonable in these cases. Due to the large sample sizes of the big data, we would be able to apply the Central Limit Theorem. This would allow us to use parametric models, such as linear regression. KNN and Decision Trees are also much harder to interpret given the methods we are thinking of using.
# <br>
#
# - Approach #2: Modelling on Temperature only
#     - This approach will not be used because we are able to link additional datasets together, extra information can only benefit us in trying to understand causes of temperature increases and decreases.
# <br><br>
#
# **What is the purpose of the data analysis, why is this important?**
# - This topic is important because it can maybe generate greater understanding of the effect of wind speed, air quality, precipitation, and air pressure on average mean temperature throughout the year.
# <br><br>
#
# **Identify the statistical rigour of the methodology you are choosing.**
# - The chosen method may have difficulties due to how we are using the data. For example, we will need to be careful about treating our explanatory variables as predictors, as these data may actually be better response variables over predictors. We also need to be careful as changes in our response variable may be attributed to other confounding variables. These datasets fulfill the necessary requirements to apply the Central Limit Theorem. In general, we are making lots of assumptions, however, we are confident that we will be able to remedy these issues within this project. Lastly, all of the datasets we have included are open source. As such, our results would be reproducible.
#
# <br><br>
# ### 5. Identify and sketch a visualization.
# After doing anaysis, we will use visualizations to convey results. Below are potential ways we will do so, using random dummy data.
# <br>
# 1. The first visualization describes changes in temperature over time.
#
# ![linear_idea1.png](attachment:f71d2129-2519-4d51-8b7d-d57e77a3881a.png)
#
# <br>

# %% [markdown]
# <br><br><br>
#
# ---
#
# ## Idea #2

# %% [markdown]
# ### 1. Explain the proposed idea.
# In hydrometric data, the height of water above a set water level is referred to as stage, measured in meters. The amount of water flowing through a stream, river, or creek at a given time is referred to as discharge measured in m^3/s. The discharge of a river is a function of velocity of flow, stage, and width of a river and is a useful predictor in determining the risk of imminent flash flooding.
#
# Rainfall directly impacts rivers by generating a local change in both stage and discharge. This idea explores the impact of changes in precipitation volume on the stage and discharge of rivers in BC using time-series data.
# <br><br>
# ### 2. Identify how the idea relates to the topic chosen by the in-class vote.
# This idea relates to climate and sustainability as changes in stage and discharge of rivers also increase the susceptibility of surrounding areas to flash floods. This can impact local communities and fauna by destroying vegetation and carrying water pollutants.
#
# Additionally, as global warming occurs, an increase in precipitation is observed as evaporation increases.
# <br><br>
#
# ### 3. List three datasets you wish to work with.
# **Dataset #1: Stage of BC Rivers from 10/2019 - 10/2021**
# - Link: https://www.env.gov.bc.ca/wsd/data_searches/water/Stage_Archive_2019Oct_2021Oct.csv
# <br>
#
# **Dataset #2: Discharge of BC Rivers 10/2019 - 10/2021**
# - Link: https://www.env.gov.bc.ca/wsd/data_searches/water/Discharge_Archive_Post_20211001.csv
# <br>
#
# **Dataset #3: Precipitation Across Different Regions in BC**
# - Link: https://catalogue.data.gov.bc.ca/dataset/86f93096-8d3d-4b68-ab63-175cc68257e6
# <br>
#
# **Trustworthiness and reliability:**
# - All three datasets are sourced from Statistics Canada’s data collection, the official government website for open source survey data in Canada. Although the data collection methods aren’t publicized, we can infer that standards are in place to ensure accuracy and reduce bias.
#
# <br><br>
# ### 4. Describe the data analysis you wish to perform. Specifically, explain:
# **What you are trying to analyze and how will you go about analyzing it?**
# - We are analyzing the relationship between precipitation and stage and discharge of rivers in BC. Specifically, we would be identifying trends in precipitation, stage, and discharge using regression and visualization techniques.
# <br><br>
#
# **Why is this the best method to analyze the data?**
# - This is the best method because our data is both time series and numerical. To identify trends between precipitation and stage, we would use a linear regression with precipitation as a predictor. To identify trends between discharge, precipitation, and stage, we would use a multiple regression with stage and precipitation as predictor variables.
# <br><br>
#
# **List two other possible ways to approach the problem and explain why you are not using these approaches.**
# - Approach #1: Using precipitation as a sole predictor of discharge
#     - This approach will not be used as although precipitation can create a localized increase in the flow rate of a river, discharge is also dependent on stage. As such, it would be more meaningful to use both precipitation and stage in a predictive model for discharge.
# <br>
# - Approach #2: Nonparametric regression (KNN)
#     - This approach will not be used because we can reasonably assume normality. As we are working with big data sets, we can infer that our sample size is sufficiently large to apply the Central Limit Theorem.
# <br><br>
#
# **What is the purpose of the data analysis, why is this important?**
# - This topic is crucial as changes in precipitation are a component of climate change. By analyzing its impact on discharge and stage, we can understand how changes in precipitation may place communities near streams and rivers at a greater risk of flooding.
# <br><br>
#
# **Identify the statistical rigour of the methodology you are choosing.**
# - Our chosen methods are easy to understand as we would be able to map out the relationship between our predictor variables and response variable. These datasets fulfill the necessary requirements to apply the CLT and thus use linear and multiple linear regression. Due to the size of our datasets, we can generalize the findings to all of BC. Additionally, since our datasets are open source, our results are reproducible.
#
# <br><br>
# ### 5. Identify and sketch a visualization.
# After doing anaysis, we will use visualizations to convey results. Below are potential ways we will do so, using random dummy data.
# <br>
#
# 1. The first visualization is a simple linear regression.
#
# ![single_lr_idea2.png](attachment:b182ae0d-0d86-45aa-8063-1ea841fde217.png)
#
# <br>
# 2. The second visualization is a multiple linear regression.
#
# ![multiple_lr_idea2.png](attachment:05cf0839-6941-4387-9e4d-ef6aaa0e3dda.png)
#
#  <br>
# <br>

# %% [markdown]
# <br><br><br>
#
# ---
#
# ## Idea #3

# %% [markdown]
# ### 1. Explain the proposed idea.
# Fuel consumption has a severe effect on the environment by creating air pollution, among other types of pollution. Burning fossil fuels release Greenhouse gasses (GHGs) into the atmosphere at unsustainable rate. GHGs are gases such as carbon dioxide methane that absorb and trap heat in the atmosphere.
# This idea investigates the relationship between fuel consumption and greenhouse emissions for various industries within Canada between 2000 and 2022. We will use employment data for these industries to calculate a per capita consumption to emission ratio that quantifies the effect of growth per industry on the environment. This per capita calculation will allow us to compare different industries on the same scale, so that we can identify trends in the main industrial contributors to greenhouse gas emissions over a 22 year period.
#
# <br><br>
# ### 2. Identify how the idea relates to the topic chosen by the in-class vote.
# This project will provide us with information on fuel consumption and greenhouse emissions to understand how industries impact the environment, and to identify those which are the most harmful to the environment. This is directly related to both climate and sustainability. Green house gas emissions are known contributors to damage to the ozone layer and changes in global climate patterns. Fuel consumption is related to sustainability because most sources of fuel are non-renewable, and thus ought to be utilized carefully. These concerns are also related to global initiatives at reducing national carbon footprints.
# ...
# This idea directly relates to the theme of sustainability by analyzing the effects of industrial growth on energy consumption and greenhouse gas production. As we will be comparing between industries, we will be able to identify which are the most harmful to the environment and how they changed between 2000 and 2022.
#
# <br><br>
#
# ### 3. List three datasets you wish to work with.
# **Dataset #1: Labour Force Characteristics by Industry**
# - Link: https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1410002301
# <br>
#
# **Dataset #2: Total Annual Energy Fuel Consumption**
# - Link: https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=2510002401&pickMembers%5B0%5D=2.1&cubeTimeFrame.startYear=1995&cubeTimeFrame.endYear=2022&referencePeriods=19950101%2C20220101
# <br>
#
# **Dataset #3: Canadian System of Environmental-Economic Accounts - Physical Flow Accounts**
# - Link: https://www23.statcan.gc.ca/imdb/p2SV.pl?Function=getSurvVariableList&Id=1530438
# <br>
#
# **Trustworthiness and reliability:**
#   - All three datasets are sourced from Statistics Canada, the official governmental website for open source survey data in Canada. Although the data collection methods aren’t publicized, we can infer that standards are in place to ensure accuracy and reduce bias.
#
# <br><br>
# ### 4. Describe the data analysis you wish to perform. Specifically, explain:
# **What you are trying to analyze and how will you go about analyzing it?**
# - We are analyzing the relationship between fuel consumption and greenhouse gas emissions and breaking it down to per capita units. Then, we will identify trends in fuel consumption and emissions using linear regression and data visualization techniques such as bar charts. By doing so, we will be able to compare various industries and identify leading contributors to emissions.
# <br><br>
#
# **Why is this the best method to analyze the data?**
# - Since we have time series numerical data, linear regression might be the most simple yet efficient way to analyze our data.
# <br><br>
#
# **List two other possible ways to approach the problem and explain why you are not using these approaches.**
# - Approach #1: Sum energy consumption and emissions across all industries
#     - This would simplify our analysis into a single general model on a national level. This is suboptimal given the aims of our project, as we would lose a significant amount of detail that can be relevant for decision making processes.
# <br>
#
# - Approach #2: Not including per capita information across all industries
#     - Not including per capita information would prevent us from making comparisons between industries of different scale. This would diminish the accuracy and reliability of information that could be gleaned from our datasets.
# <br><br>
#
# **What is the purpose of the data analysis, why is this important?**
# - This topic is important because identification of key unsustainable industries can help guide policy-makers to impose restrictions on these industries, while divesting into more sustainable options.
# <br><br>
#
# **Identify the statistical rigour of the methodology you are choosing.**
# - The chosen method is easy and intuitive to interpret and it will allow us to easily compare trends across industries and visualize our findings. Our datasets are sufficiently larget to meet the assumptions required to use linear regression through the Central Limit Theorem. Ensuring these assumptions are met maintains the integrity of our findings and allows us to generalize findings to all of Canada. Lastly, due to the datasets being public access, the results are replicable.
#
#
# <br><br>
# ### 5. Identify and sketch a visualization.
# After doing anaysis, we will use visualizations to convey results. Below are potential ways we will do so, using random dummy data.
# <br>
# 1. The first visualization is a bar graph that will compare the average overall emissions for industries.
#
# ![bar.png](attachment:d9f6eb90-8810-43c9-934b-6d2ebb781dad.png)
#
# <br>
# 2. The second visualization is a time series graph that shows how emissions has changed over time for various industries.
#
# ![line_idea3.png](attachment:01068a8f-c118-4621-b799-218fd2672a45.png)
# <br>

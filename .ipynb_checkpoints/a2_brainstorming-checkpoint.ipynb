# %% [markdown]
# # CPSC 368 Group Project Brainstorming
# <br><br>

# %% [markdown]
# ## Idea #1

# %% [markdown]
# ### 1. Explain the proposed idea.
# This idea will connect temperature, precipitation, pressure, air quality, and wind speed in cities across the lower mainland to determine patterns among them. Specifically, we want to look at what may cause rapid increase and decrease in temperatures across the lower mainland.
#
# <br><br>
# ### 2. Identify how the idea relates to the topic chosen by the in-class vote.
# This idea is related to climate and sustainability since we are directly analyzing the climate of the lower mainland. We are wanting to look at the climate and look into causes of higher or lower temperatures.
# <br><br>
#
# ### 3. List three datasets you wish to work with.
# **Dataset #1:**
# - Link: https://www.canada.ca/en/environment-climate-change/services/climate-change/science-research-data/climate-trends-variability/adjusted-homogenized-canadian-data/surface-air-temperature.html
# - Trustworthiness and reliability: Homogenized Surface Air Temperature Data - Directly from the Canadian Government's website.
# <br><br>
#
# **Dataset #2:**
# - Link: https://www.canada.ca/en/environment-climate-change/services/climate-change/science-research-data/climate-trends-variability/adjusted-homogenized-canadian-data/precipitation.html
# - Trustworthiness and reliability: Adjusted Precipitation Data - Directly from the Canadian Government's website.
# <br><br>
#
# **Dataset #3:**
# - Link: https://www.canada.ca/en/environment-climate-change/services/climate-change/science-research-data/climate-trends-variability/adjusted-homogenized-canadian-data/surface-pressure.html
# - Trustworthiness and reliability: Homogenized Surface Pressure Data - Directly from the Canadian Government's website.
# <br><br>
#
# **Dataset #4:**
# - Link: https://www.canada.ca/en/environment-climate-change/services/climate-change/science-research-data/climate-trends-variability/adjusted-homogenized-canadian-data/surface-wind-speed.html
# - Trustworthiness and reliability: Homogenized Surface Wind Speed Data - Directly from the Canadian Government's website.
# <br><br>
#
# **Dataset #5:**
# - Link: https://catalogue.data.gov.bc.ca/dataset/air-quality-and-climate-monitoring-verified-hourly-air-quality-and-meteorological-data
# - Trustworthiness and reliability: Verified Air Quality Readings across BC. Directly from the BC Government's website.
# <br><br>
# ### 4. Describe the data analysis you wish to perform. Specifically, explain:
# **What you are trying to analyze and how will you go about analyzing it?**
# - We are analyzing potential patterns based on climate data to see if any affect average temperatures in the year. Through this, we can also look at potential causes for changes in the trend of the temperature around BC/the lower mainland. This plan may require modelling, either linear or some other method, to achieve this.
# <br><br>
#
# **Why is this the best method to analyze the data?**
# - This is the best method because we are wanting to make inference on the data, and perhaps use this to predict future average temperatures given trends of other data. Instead of fitting a model on just temperature data alone, we can use air quality, wind, pressure, and many others to help with the analysis.
# <br><br>
#
# **List two other possible ways to approach the problem and explain why you are not using these approaches.**
# - Approach #1: Non-parametric regression (KNN, Decision Trees)
#     - This approach will not be used because assumptions of normality may be reasonable in these cases. We will need to check over the course of our project, but our current assumption is that we can apply parametric regression and models for this. KNN and Decision Trees are also much harder to interpret the methods we are thinking of using.
# <br>
#
# - Approach #2: Modelling on Temperature only
#     - This approach will not be used because we are able to link additional datasets together, extra information can only benefit us in trying to understand causes of temperature increases and decreases.
# <br><br>
#
# **What is the purpose of the data analysis, why is this important?**
# - This topic is important because it can maybe generate greater understanding in the effect of wind speed, air quality, precipitation, and air pressure on average mean temperature throughout the months.
# <br><br>
#
# **Identify the statistical rigour of the methodology you are choosing.**
# - The chosen method may have some doubts, specifically how we are using the data. For example, we will need to be careful about treating our explanatory variables as predictors, as these data may actually be better responses over predictors. We also need to be careful about making sure that our variables may be changing due to other factors as well. We are making lots of assumptions, making the world much simpler than it already is. However, we are confident that we will be able to remedy these issues within this project.
#
# <br><br>
# ### 5. Identify and sketch a visualization.
# <br>

# %% [markdown]
# <br><br><br>
#
# ---
#
# ## Idea #2

# %% [markdown]
# ### 1. Explain the proposed idea.
# This idea ...
# <br><br>
# ### 2. Identify how the idea relates to the topic chosen by the in-class vote.
# This idea is related to climate and sustainability ...
# <br><br>
#
# ### 3. List three datasets you wish to work with.
# **Dataset #1:**
# - Link:
# - Trustworthiness and reliability:
# <br><br>
#
# **Dataset #2:**
# - Link:
# - Trustworthiness and reliability:
# <br><br>
#
# **Dataset #3:**
# - Link:
# - Trustworthiness and reliability:
# <br><br>
# ### 4. Describe the data analysis you wish to perform. Specifically, explain:
# **What you are trying to analyze and how will you go about analyzing it?**
# - We are analyzing ...
# <br><br>
#
# **Why is this the best method to analyze the data?**
# - This is the best method because ...
# <br><br>
#
# **List two other possible ways to approach the problem and explain why you are not using these approaches.**
# - Approach #1: ...
#     - This approach will not be used because ...
# <br>
#
# - Approach #2: ...
#     - This approach will not be used because ...
# <br><br>
#
# **What is the purpose of the data analysis, why is this important?**
# - This topic is important because ...
# <br><br>
#
# **Identify the statistical rigour of the methodology you are choosing.**
# - The chosen method is ...
#
# <br><br>
# ### 5. Identify and sketch a visualization.
# <br>

# %% [markdown]
# <br><br><br>
#
# ---
#
# ## Idea #3

# %% [markdown]
# ### 1. Explain the proposed idea.
# Using various datasets, we will investigate the correlation between fuel consumption and greenhouse emissions for various industries within Canada. We will investigate the relationship between the two and how they have changed between 2000 and 2022, and use employment data for these industries to calculate a per capita consumption to emission ratio. This per capita calculation will allows us to compare different industries on the same scale, so that we can identify trends in the main industrial contributors to greenhouse gas emissions over a 22 year period.
# <br><br>
# ### 2. Identify how the idea relates to the topic chosen by the in-class vote.
# This project will provide us with information on fuel consumption and greenhouse emissions to understand how industries impact the environment, and to identify those which are the most harmful to the environment. This is directly related to both climate and sustainability. Green house gas emissions are known contributors to damage to the ozone layer and changes in global climate patterns. Fuel consumption is related to sustainability because most sources of fuel are non-renewable, and thus ought to be utilized carefully. These concerns are also related to global initiatives at reducing national carbon footprints.
# <br><br>
#
# ### 3. List three datasets you wish to work with.
# **Dataset #1: Labour Force Characteristics by Industry**
# - Link: https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1410002301
# <br><br>
#
# **Dataset #2: Total Annual Energy Fuel Consumption**
# - Link: https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=2510002401&pickMembers%5B0%5D=2.1&cubeTimeFrame.startYear=1995&cubeTimeFrame.endYear=2022&referencePeriods=19950101%2C20220101
# <br><br>
#
# **Dataset #3: Canadian System of Environmental-Economic Accounts - Physical Flow Accounts**
# - Link: https://www23.statcan.gc.ca/imdb/p2SV.pl?Function=getSurvVariableList&Id=1530438
# <br><br>
# - Trustworthiness and reliability: All three datasets are sourced from Statistics Canada, the official governmental website for survey data in Canada. We can trust that the data was collected with measures to reduce bias, ensure accuracy, and preserve legitimacy.
# <br><br>
# ### 4. Describe the data analysis you wish to perform. Specifically, explain:
# **What you are trying to analyze and how will you go about analyzing it?**
# - We are analyzing the relationship between fuel consumption and green house gas emission and breaking it down to per capita units. We will use linear regression to model the relationship between fuel consumption and green house gas emissions. By doing so, we will be able to use visualizations such as bar charts to compare various industries and identify leading contributors to emissions.
# <br><br>
#
# **Why is this the best method to analyze the data?**
# - Since we have time series numerical data, linear regression might be the most simple yet efficient way to analyze our data.
# <br><br>
#
# **List two other possible ways to approach the problem and explain why you are not using these approaches.**
# - Approach #1:
#     - We could sum the energy consumption and emissions for all industries to get an image of the relationship between the two on a national, more generalized scale. However, by doing so we will loose a significant amount of detail that would be helpful for identifying problematic industries. This is important to us because we want to give readers of our analysis data that can help in decision making and policy development for environmentally friendly initiatives.
# <br>
#
# - Approach #2:
#     - Another approach would be to not include the per capita numbers for industries. Instead, we would analyze the trends in individual industries as a whole over 22 years. However, this would prevent us from accurately comparing different sized industries. Having a base unit that is the same across all industries is necessary for an accurate analysis of each industry's effects.
# <br><br>
#
# **What is the purpose of the data analysis, why is this important?**
# - This topic is important because identification of the key unsustainable industries can help decision makers to identify gaps in existing environmental policy and innovate new means of addressing emissions problems specific to single industries.
# <br><br>
#
# **Identify the statistical rigour of the methodology you are choosing.**
# - Linear regression is easy and intuitive to interpret and it will allow us to easily compare trends across industries and visualize our findings. Our datasets also meet the assumptions required to use linear regression, such as variables being normally distributed. Ensuring these assumptions are met maintains the integrity of our findings. We are also using large sample sizes, which can ensure the ability to generalize findings to all of Canada. In general the model will likely be uncomplicated, and easy to replicate.
#
# <br><br>
# ### 5. Identify and sketch a visualization.
# <br>
